# %% [markdown]
# # Percapita FONASA

# %% [markdown]
# ### Carga archivo Excel en un DataFrame y mostrar las primeras filas para verificar la carga.

# %%
import pandas as pd
import sys
sys.path.append('/Users/renzovergara/Documents/Proyectos/analisis-rem-2024')
from utils.clean_data import clean_data

df = pd.read_excel(r'/Users/renzovergara/Documents/Proyectos/analisis-rem-2024/Data/muestra-percapita/Muestra percapita FONASA.xlsx')
df_clean = clean_data(df.copy())
df_clean
# Out:
#                                         NOMBRE_CENTRO  RUT_count
# 12             Centro De Salud FamiliarQuebrada Verde       1088
# 9                Centro De Salud FamiliarMarcelo Mena        552
# 6                       Centro De Salud FamiliarBarón        513
# 5            Centro De Salud Familiar Reina Isabel II        464
# 4                   Centro De Salud Familiar Placeres        438
# 10      Centro De Salud FamiliarPlacilla (Valparaíso)        367
# 13                  Centro De Salud FamiliarRodelillo        317
# 11             Centro De Salud FamiliarPuertas Negras        256
# 7                  Centro De Salud FamiliarCordillera        252
# 8                   Centro De Salud FamiliarEsperanza        251
# 3       Centro De Salud Familiar Padre Damián Molokai        200
# 2                  Centro De Salud Familiar Las Cañas        146
# 14                  Posta De Salud Rural Laguna Verde        112
# 0                   CECOSF Juan Pablo II De Rodelillo         17
# 1   Centro Comunitario De Salud Familiar Porvenir ...         13
