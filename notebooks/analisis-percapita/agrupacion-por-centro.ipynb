# %% [markdown]
# # Percapita FONASA

# %% [markdown]
# ### Carga archivo Excel en un DataFrame y mostrar las primeras filas para verificar la carga.

# %%
import pandas as pd
import sys

sys.path.append('/Users/renzovergara/Documents/Proyectos/analisis-rem-2024')
from utils.clean_data import clean_data_percapita


df = pd.read_excel(r'/Users/renzovergara/Documents/Proyectos/analisis-rem-2024/Data/percapita/Percapita FONASA 09-2024.xlsx')
df_clean = clean_data_percapita(df.copy())
df_clean
# Out:
#                                         NOMBRE_CENTRO  CENTRO_count
# 12             Centro De Salud FamiliarQuebrada Verde           329
# 4                   Centro De Salud Familiar Placeres           323
# 10      Centro De Salud FamiliarPlacilla (Valparaíso)           317
# 13                  Centro De Salud FamiliarRodelillo           298
# 9                Centro De Salud FamiliarMarcelo Mena           291
# 5            Centro De Salud Familiar Reina Isabel II           280
# 6                       Centro De Salud FamiliarBarón           269
# 14                  Posta De Salud Rural Laguna Verde           252
# 8                   Centro De Salud FamiliarEsperanza           240
# 2                  Centro De Salud Familiar Las Cañas           229
# 7                  Centro De Salud FamiliarCordillera           224
# 3       Centro De Salud Familiar Padre Damián Molokai           221
# 11             Centro De Salud FamiliarPuertas Negras           220
# ...
