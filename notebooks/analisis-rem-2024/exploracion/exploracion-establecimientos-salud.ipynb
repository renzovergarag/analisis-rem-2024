# %% [markdown]
# # Analisis de la BD de establecimientos de Valparaiso

# %% [markdown]
# ### Importación de librerías

# %%
import pandas as pd

# %% [markdown]
# ### Cargar datos desde el origen (carpeta Data)

# %%
df =    pd.read_excel(
            r'/Users/renzovergara/Documents/Proyectos/analisis-rem-2024/Data/establecimientos-salud/Establecimientos DEIS MINSAL 25-11-2025.xlsx',
            sheet_name='ESTABLECIMIENTO_2025-11-25', header=1, usecols=["Código Vigente", "Nombre Oficial","Código Comuna", "Nombre Comuna",],
        )
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/analisis-de-datos/lib/python3.13/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %% [markdown]
# ### Ver informacion de los tipos de datos en el DF

# %%
df_establecimientos_valparaiso =df.query("`Código Comuna` == 5101")
df_establecimientos_valparaiso.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 546 to 4989
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Código Vigente  74 non-null     int64
#  1   Nombre Oficial  74 non-null     object
#  2   Código Comuna   74 non-null     float64
#  3   Nombre Comuna   74 non-null     object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.9+ KB

# %% [markdown]
# ### Ver estadisticas de la columnas numerias

# %%
df_establecimientos_valparaiso.describe()
# Out:
#        Código Vigente  Código Comuna
# count       74.000000           74.0
# mean    135645.864865         5101.0
# std      44037.841976            0.0
# min     106010.000000         5101.0
# 25%     106241.250000         5101.0
# 50%     106304.500000         5101.0
# 75%     200292.750000         5101.0
# max     202054.000000         5101.0

# %% [markdown]
# ### Mostrar los primeros registros del DF

# %%
df_establecimientos_valparaiso.head()
# Out:
#       Código Vigente                                     Nombre Oficial  \
# 546           106240                 Centro Dental Árabe Miguel Jahiatt
# 3133          106804                                      SAPU Placilla
# 3134          106304                  Centro de Salud Familiar Placilla
# 3135          200731                                   SUR Laguna Verde
# 3136          106401  Centro Comunitario de Salud Familiar Laguna Verde
#
#       Código Comuna Nombre Comuna
# 546          5101.0    Valparaíso
# 3133         5101.0    Valparaíso
# 3134         5101.0    Valparaíso
# 3135         5101.0    Valparaíso
# 3136         5101.0    Valparaíso

# %% [markdown]
# ### Listar encabezados de cada columna

# %%
print(df.columns.tolist())
# Out:
# ['Código Vigente', 'Nombre Oficial', 'Código Comuna', 'Nombre Comuna']
