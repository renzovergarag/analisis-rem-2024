# %% [markdown]
# # Analisis Exploratorio BD de establecimientos de Salud

# %% [markdown]
# ### Importación de librerías

# %%
import pandas as pd

# %% [markdown]
# ### Cargar datos desde el origen (carpeta Data)

# %%
df =    pd.read_excel(
            r'/Users/renzovergara/Documents/Proyectos/analisis-rem-2024/Data/establecimientos-salud/Establecimientos DEIS MINSAL 25-11-2025.xlsx',
            sheet_name='ESTABLECIMIENTO_2025-11-25', header=1,
        )
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/analisis-de-datos/lib/python3.13/site-packages/openpyxl/worksheet/_read_only.py:85: UserWarning: Data Validation extension is not supported and will be removed
#   for idx, row in parser.parse():

# %% [markdown]
# ### Tipos de datos en el DF

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5146 entries, 0 to 5145
# Data columns (total 32 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   Código Antiguo                                              5146 non-null   object
#  1   Código Vigente                                              5146 non-null   int64
#  2   Código  Madre Antiguo                                       938 non-null    object
#  3   Código Madre Nuevo                                          934 non-null    object
#  4   Código Región                                               5146 non-null   int64
#  5   Nombre Región                                               5146 non-null   object
#  6   Código Dependencia Jerárquica (SEREMI / Servicio de Salud)  5146 non-null   object
# ...

# %% [markdown]
# ### Estadisticas de la columnas numerias

# %%
df.describe()
# Out:
#        Código Vigente  Código Región  Código Comuna
# count     5146.000000    5146.000000    5144.000000
# mean    149424.799067       8.651185    8841.889386
# std      42150.737460       3.948524    3931.264009
# min     101010.000000       1.000000    1101.000000
# 25%     114316.250000       5.000000    5602.000000
# 50%     123212.500000       8.000000    8311.000000
# 75%     200848.750000      13.000000   13110.000000
# max     211557.000000      16.000000   16305.000000

# %% [markdown]
# ### Primeros registros del DF (Head)

# %%
df.head()
# Out:
#   Código Antiguo   Código Vigente Código  Madre Antiguo Código Madre Nuevo  \
# 0          26-704          126704                   NaN                NaN
# 1          26-204          126204                   NaN                NaN
# 2          26-412          126412                   NaN                NaN
# 3          26-414          126414                   NaN                NaN
# 4          26-102          126102                   NaN                NaN
#
#    Código Región                                   Nombre Región  \
# 0             12  Región de Magallanes y de la Antártica Chilena
# 1             12  Región de Magallanes y de la Antártica Chilena
# 2             12  Región de Magallanes y de la Antártica Chilena
# 3             12  Región de Magallanes y de la Antártica Chilena
# 4             12  Región de Magallanes y de la Antártica Chilena
#
#   Código Dependencia Jerárquica (SEREMI / Servicio de Salud)  \
# 0                                                 26
# ...

# %% [markdown]
# ### Listado de columnas (Encabezados)

# %%
print(df.columns.tolist())
# Out:
# ['Código Antiguo ', 'Código Vigente', 'Código  Madre Antiguo', 'Código Madre Nuevo', 'Código Región', 'Nombre Región', 'Código Dependencia Jerárquica (SEREMI / Servicio de Salud)', 'Nombre Dependencia Jerárquica (SEREMI / Servicio de Salud)', 'Pertenencia al SNSS', 'Tipo Establecimiento (Unidad)', 'Ámbito de Funcionamiento', 'Nombre Oficial', 'Certificación ', 'Dependencia Administrativa', 'Nivel de Atención', 'Código Comuna', 'Nombre Comuna', 'Vía', 'Número', 'Dirección', 'Teléfono', 'Fecha Inicio Funcionamiento', 'Tiene Servicio de Urgencia', 'Tipo de Urgencia ', 'Clasificación Tipo de SAPU', 'LATITUD [Grados decimales]', 'LONGITUD [Grados decimales]', 'Tipo de Prestador Sistema de Salud', 'Estado de Funcionamiento', 'Nivel de Complejidad', 'Tipo de Atención ', 'Fecha de Incorporación a la base ']

# %% [markdown]
# ### Listado de categorias de la columna 'Nivel de Atención'

# %%
niveles_atencion = df['Nivel de Atención'].unique()
niveles_atencion.sort()
print(niveles_atencion)
# Out:
# ['No Aplica' 'Pendiente' 'Primario' 'Primario ' 'Secundario' 'Terciario']

# %% [markdown]
# ### Listado de categorias de la columna  'Dependencia Administrativa'

# %%
dependencias_administrativas = df['Dependencia Administrativa'].unique()
# dependencias_administrativas.sort()
print(dependencias_administrativas)
# Out:
# ['Servicio de Salud' 'Fuerzas Armadas y de Orden (FFAA)' 'Municipal'
#  'Privado' 'SEREMI de Salud' 'Gendamería' 'Otra Institución' 'Delegados '
#  nan 'Corporación Municipal ' 'Municipal ']
