# %%
# Se ha cargado la variable "df" del URI: /Users/renzovergara/Documents/Proyectos/Piloto Python/Comparativa FONASA.xlsx
import pandas as pd
df = pd.read_excel(r'/Users/renzovergara/Documents/Proyectos/Piloto Python/Comparativa FONASA.xlsx')
df.head()
# Out:
#   Source.Name         RUT                  NOMBRES APELLIDO_PATERNO  \
# 0  2025-04-01  16802623-4           JORGE BENJAMÍN         GALLARDO
# 1  2025-04-01   5964294-4             MARCELA INÉS         GALLARDO
# 2  2025-04-01  26713061-2             MATEO ALONSO           BARRÍA
# 3  2025-04-01   9913830-0        SANDRA DEL CARMEN         SAAVEDRA
# 4  2025-04-01  23753685-1  ANAÍS IGNACIA ANTONELLA            SILVA
#
#   APELLIDO_MATERNO FECHA_NACIMIENTO  GENERO TRAMO FECHA_CORTE  COD_CENTRO  \
# 0           ARANDA       1987-05-21  HOMBRE     A  2025-04-30      106303
# 1       VILLALOBOS       1947-07-18   MUJER     B  2025-04-30      106306
# 2            ACUÑA       2019-02-19  HOMBRE     C  2025-04-30      106307
# 3            ARAYA       1963-11-02   MUJER     B  2025-04-30      106307
# 4       SANTIBÁÑEZ       2011-09-23   MUJER     C  2025-04-30      106307
#
#    ... TRASLADO_POSITIVO  TRASLADO_NEGATIVO NUEVO_INSCRITO  EXBLOQUEADO  \
# 0  ...               NaN                NaN            NaN          NaN
# 1  ...               NaN                NaN            NaN          NaN
# 2  ...               NaN                NaN            NaN          NaN
# 3  ...               NaN                NaN            NaN          NaN
# 4  ...               NaN                NaN            NaN          NaN
#
#   RECHAZADO_PREVISIONAL  RECHAZADO_FALLECIDO  AUTORIZADO  ACEPTADO_RECHAZADO  \
# 0                   NaN                  NaN           X            ACEPTADO
# 1                   NaN                  NaN           X            ACEPTADO
# 2                   NaN                  NaN           X            ACEPTADO
# 3                   NaN                  NaN           X            ACEPTADO
# 4                   NaN                  NaN           X            ACEPTADO
#
#                  MOTIVO Consolidado.RUT
# 0  MANTIENE INSCRIPCIÓN             NaN
# 1  MANTIENE INSCRIPCIÓN             NaN
# 2  MANTIENE INSCRIPCIÓN             NaN
# 3  MANTIENE INSCRIPCIÓN             NaN
# 4  MANTIENE INSCRIPCIÓN             NaN
#
# [5 rows x 29 columns]
